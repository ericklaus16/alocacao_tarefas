# %%
# caminho_arq = str(input("Qual arquivo você deseja abrir? "))
caminho_arq = "entrada.txt"

horarios_inicio = []
horarios_fim = []

escalonamento = []

contador = 0
with open(caminho_arq, 'r') as arq:
    for linha in arq:
        if contador == 0:
            horarios_inicio = list(map(int, linha.strip().split(" ")))
            contador += 1
        else:
            horarios_fim = list(map(int, linha.strip().split(" ")))

def temRecursoDisponivel(inicio, fim):
    for idx, recurso in enumerate(escalonamento):
        conflito = False

        for ocupado_inicio, ocupado_fim in recurso:
            # Duas tarefas conflitam se há sobreposição no tempo
            # NÃO conflitam se: nova termina antes/quando existente começa OU nova começa depois/quando existente termina
            if not (fim <= ocupado_inicio or inicio >= ocupado_fim):
                conflito = True
                break
                
        if not conflito:
            print(f"Recurso {idx+1} DISPONÍVEL para tarefa ({inicio},{fim})")
            return idx  # Este recurso pode acomodar a nova tarefa
        # else:
        #     print(f"Recurso {idx+1} OCUPADO")
            
    print(f"Nenhum recurso disponível para ({inicio},{fim}), criando novo recurso!")
    return False

while len(horarios_inicio) != 0:
    primeira = True
    menor = min(horarios_inicio)
    indice = horarios_inicio.index(menor)
    fim_horario = horarios_fim[indice]

    print(f"Analisando tarefa [{menor}, {fim_horario}]")
    
    recursoDisponivel = temRecursoDisponivel(menor, fim_horario)

    if recursoDisponivel is False:     
        escalonamento.append([(menor, fim_horario)])
    else:
        escalonamento[recursoDisponivel].append((menor, fim_horario))
    
    horarios_inicio.pop(indice)
    horarios_fim.pop(indice)

for i, recurso in enumerate(escalonamento):
    print(f"Recurso {i + 1}: {recurso}")
    
print("\n=== ESTATÍSTICAS ===")
for i, recurso in enumerate(escalonamento):
    tempo_total = sum(fim - inicio for inicio, fim in recurso)
    print(f"Recurso {i + 1}: {len(recurso)} tarefas, {tempo_total} unidades de tempo")
# Out:
# Analisando tarefa [1, 5]
# Nenhum recurso disponível para (1,5), criando novo recurso!
# Analisando tarefa [1, 9]
# Nenhum recurso disponível para (1,9), criando novo recurso!
# Analisando tarefa [1, 8]
# Nenhum recurso disponível para (1,8), criando novo recurso!
# Analisando tarefa [2, 8]
# Nenhum recurso disponível para (2,8), criando novo recurso!
# Analisando tarefa [3, 6]
# Nenhum recurso disponível para (3,6), criando novo recurso!
# Analisando tarefa [4, 12]
# Nenhum recurso disponível para (4,12), criando novo recurso!
# Analisando tarefa [5, 12]
# Recurso 1 DISPONÍVEL para tarefa (5,12)
# Analisando tarefa [7, 11]
# Recurso 5 DISPONÍVEL para tarefa (7,11)
# Analisando tarefa [8, 12]
# Recurso 3 DISPONÍVEL para tarefa (8,12)
# Analisando tarefa [11, 17]
# Recurso 2 DISPONÍVEL para tarefa (11,17)
# Analisando tarefa [13, 23]
# Recurso 1 DISPONÍVEL para tarefa (13,23)
# Analisando tarefa [13, 27]
# Recurso 3 DISPONÍVEL para tarefa (13,27)
# Analisando tarefa [14, 17]
# Recurso 4 DISPONÍVEL para tarefa (14,17)
# Analisando tarefa [15, 19]
# Recurso 5 DISPONÍVEL para tarefa (15,19)
# Analisando tarefa [21, 23]
# Recurso 2 DISPONÍVEL para tarefa (21,23)
# Recurso 1: [(1, 5), (5, 12), (13, 23)]
# Recurso 2: [(1, 9), (11, 17), (21, 23)]
# Recurso 3: [(1, 8), (8, 12), (13, 27)]
# Recurso 4: [(2, 8), (14, 17)]
# Recurso 5: [(3, 6), (7, 11), (15, 19)]
# Recurso 6: [(4, 12)]
#
# === ESTATÍSTICAS ===
# Recurso 1: 3 tarefas, 21 unidades de tempo
# Recurso 2: 3 tarefas, 16 unidades de tempo
# Recurso 3: 3 tarefas, 25 unidades de tempo
# Recurso 4: 2 tarefas, 9 unidades de tempo
# Recurso 5: 3 tarefas, 11 unidades de tempo
# Recurso 6: 1 tarefas, 8 unidades de tempo

# %%
# caminho_arq = str(input("Qual arquivo você deseja abrir? "))
caminho_arq = "entrada.txt"

horarios_inicio = []
horarios_fim = []

escalonamento = []

contador = 0
with open(caminho_arq, 'r') as arq:
    for linha in arq:
        if contador == 0:
            horarios_inicio = list(map(int, linha.strip().split(" ")))
            contador += 1
        else:
            horarios_fim = list(map(int, linha.strip().split(" ")))

def temRecursoDisponivel(inicio, fim):
    recursos_disponiveis = {} # Armazena as salas disponíveis
    
    print(f"  Testando {len(escalonamento)} recursos existentes...")
    
    for idx, recurso in enumerate(escalonamento):
        conflito = False

        for ocupado_inicio, ocupado_fim in recurso:
            # Duas aulas conflitam se há sobreposição no tempo
            # NÃO conflitam se: nova termina antes/quando existente começa OU nova começa depois/quando existente termina
            if not (fim <= ocupado_inicio or inicio >= ocupado_fim):
                conflito = True
                break
                
        if not conflito:
            tempo_total = 0
            for ocupado_inicio, ocupado_fim in recurso:
                tempo_total += ocupado_fim - ocupado_inicio
                
            recursos_disponiveis[idx] = tempo_total # Armazena o tempo total ocupado por esta sala
            
            print(f"Sala {idx+1} DISPONÍVEL para aula ({inicio},{fim})")
        # else:
        #     print(f"Recurso {idx+1} OCUPADO")
        
    if recursos_disponiveis:
        melhor_recurso = min(recursos_disponiveis, key=recursos_disponiveis.get)
        print(f"  → ESCOLHIDA: Sala {melhor_recurso+1}")
        return melhor_recurso
    else: 
        print(f"  → CRIANDO nova sala!")
        return False

while len(horarios_inicio) != 0:
    primeira = True
    menor = min(horarios_inicio)
    indice = horarios_inicio.index(menor)
    fim_horario = horarios_fim[indice]

    print(f"Analisando aula [{menor}, {fim_horario}]")
    
    recursoDisponivel = temRecursoDisponivel(menor, fim_horario)

    if recursoDisponivel is False:     
        escalonamento.append([(menor, fim_horario)])
    else:
        escalonamento[recursoDisponivel].append((menor, fim_horario))
    
    horarios_inicio.pop(indice)
    horarios_fim.pop(indice)

for i, recurso in enumerate(escalonamento):
    print(f"Sala {i + 1}: {recurso}")
# Out:
# Analisando aula [1, 5]
#   Testando 0 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [1, 9]
#   Testando 1 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [1, 8]
#   Testando 2 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [2, 8]
#   Testando 3 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [3, 6]
#   Testando 4 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [4, 12]
#   Testando 5 recursos existentes...
#   → CRIANDO nova sala!
# Analisando aula [5, 12]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (5,12)
#   → ESCOLHIDA: Sala 1
# Analisando aula [7, 11]
#   Testando 6 recursos existentes...
# Sala 5 DISPONÍVEL para aula (7,11)
#   → ESCOLHIDA: Sala 5
# Analisando aula [8, 12]
#   Testando 6 recursos existentes...
# Sala 3 DISPONÍVEL para aula (8,12)
# Sala 4 DISPONÍVEL para aula (8,12)
#   → ESCOLHIDA: Sala 4
# Analisando aula [11, 17]
#   Testando 6 recursos existentes...
# Sala 2 DISPONÍVEL para aula (11,17)
# Sala 3 DISPONÍVEL para aula (11,17)
# Sala 5 DISPONÍVEL para aula (11,17)
#   → ESCOLHIDA: Sala 3
# Analisando aula [13, 23]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (13,23)
# Sala 2 DISPONÍVEL para aula (13,23)
# Sala 4 DISPONÍVEL para aula (13,23)
# Sala 5 DISPONÍVEL para aula (13,23)
# Sala 6 DISPONÍVEL para aula (13,23)
#   → ESCOLHIDA: Sala 5
# Analisando aula [13, 27]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (13,27)
# Sala 2 DISPONÍVEL para aula (13,27)
# Sala 4 DISPONÍVEL para aula (13,27)
# Sala 6 DISPONÍVEL para aula (13,27)
#   → ESCOLHIDA: Sala 2
# Analisando aula [14, 17]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (14,17)
# Sala 4 DISPONÍVEL para aula (14,17)
# Sala 6 DISPONÍVEL para aula (14,17)
#   → ESCOLHIDA: Sala 6
# Analisando aula [15, 19]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (15,19)
# Sala 4 DISPONÍVEL para aula (15,19)
#   → ESCOLHIDA: Sala 4
# Analisando aula [21, 23]
#   Testando 6 recursos existentes...
# Sala 1 DISPONÍVEL para aula (21,23)
# Sala 3 DISPONÍVEL para aula (21,23)
# Sala 4 DISPONÍVEL para aula (21,23)
# Sala 6 DISPONÍVEL para aula (21,23)
#   → ESCOLHIDA: Sala 1
# Sala 1: [(1, 5), (5, 12), (21, 23)]
# Sala 2: [(1, 9), (13, 27)]
# Sala 3: [(1, 8), (11, 17)]
# Sala 4: [(2, 8), (8, 12), (15, 19)]
# Sala 5: [(3, 6), (7, 11), (13, 23)]
# Sala 6: [(4, 12), (14, 17)]
